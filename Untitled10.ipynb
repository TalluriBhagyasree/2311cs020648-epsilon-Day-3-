# %% [markdown]
# <a href="https://colab.research.google.com/github/TalluriBhagyasree/2311cs020648-epsilon-Day-3-/blob/main/Untitled10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm
import matplotlib.pyplot as plt

np.random.seed(42)
X = np.random.rand(100, 1)
y = 3 * X.squeeze() + np.random.randn(100)

X = sm.add_constant(X)

model = sm.OLS(y, X).fit()

qqplot = sm.qqplot(model.resid, line='q')
plt.title("Normal Q-Q plot of residuals")
plt.show()
